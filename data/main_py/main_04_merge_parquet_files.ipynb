# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Mar 30 15:14:05 2023

@author: localadmin
"""
import os
import sys
import pandas as pd
from pathlib import Path
sys.path.append(os.path.join('..','func_py'))

def my_func_all_files(path_beats_loc):
    isExist = os.path.exists(path_beats_loc)
    if not isExist:
        list_of_files_loc = []
    else:
        list_of_files_loc = sorted( filter( lambda x: os.path.isfile(os.path.join(path_beats_loc, x)),
                                os.listdir(path_beats_loc) ) )
        
    return list_of_files_loc

def my_func_concate_df(list_of_files_loc,path_input):
    flag_new_UID = True
    total_ii = len(list_of_files_loc)
    for count_ii,this_file_name in enumerate(list_of_files_loc):
        # Read parquet file.
        print('Debug:',count_ii,'/',total_ii,':',this_file_name)
        df_test_loc = pd.read_parquet(os.path.join(path_input,this_file_name), engine="fastparquet")
        print('Debug:',df_test_loc.columns)
        # Save it in a dataframe.
        if flag_new_UID:
            df_Beats_Loc_all = df_test_loc.copy()
            flag_new_UID = False
        else:
            df_Beats_Loc_all = pd.concat([df_Beats_Loc_all,df_test_loc], axis=1)
        # Close the parquet file.

    print('Finished concatenate the UID',UID)
    return df_Beats_Loc_all

def my_func_for_loop(path_input,path_output,appendix_name):
    list_of_files = my_func_all_files(path_input)
    if len(list_of_files) > 0:
        df_all = my_func_concate_df(list_of_files,path_input)
        
        # Save the bigger parquet file for each UID.  
        temp_file = os.path.join(path_output,UID+appendix_name)
        df_all.to_parquet(temp_file, compression=None)
        print('Path is:',temp_file)
        return True
    else:
        df_all = []
        return False
    
# Get all the UIDs that were generated by MATLAB.
get_UID_list = r'/mnt/r/ENGR_Chon/NIH_Pulsewatch_Database/mat_for_load_Final_Clinical_Trial_Data'
dir_list_UID = os.listdir(get_UID_list)
first_3_char = list(set([x[:3] for x in dir_list_UID]))
first_3_char_unique = [x for x in first_3_char if x[0] == '0' or x[0] == '1']
# first_3_char_unique = [x for x in first_3_char if x[0] == '3' or x[0] == '4']
first_3_char_unique.sort()

path_beats_loc = r'/mnt/r/ENGR_Chon/NIH_Pulsewatch_Database/Parquet_Files/Solo_Beats_Loc'
path_beats_rhythm = r'/mnt/r/ENGR_Chon/NIH_Pulsewatch_Database/Parquet_Files/Solo_Beats_Rhythm'
path_beats_type = r'/mnt/r/ENGR_Chon/NIH_Pulsewatch_Database/Parquet_Files/Solo_Beats_Type'
path_ECG_valid = r'/mnt/r/ENGR_Chon/NIH_Pulsewatch_Database/Parquet_Files/Solo_ECG_Valid'
path_ECG_raw = r'/mnt/r/ENGR_Chon/NIH_Pulsewatch_Database/Parquet_Files/Solo_ECG_Raw'
path_ECG_timestamp = r'/mnt/r/ENGR_Chon/NIH_Pulsewatch_Database/Parquet_Files/Solo_ECG_Timestamp'


path_beats_loc_output = path_beats_loc+'_each_UID'
path_beats_rhythm_output = path_beats_rhythm+'_each_UID'
path_beats_type_output= path_beats_type+'_each_UID'
path_ECG_valid_output = path_ECG_valid+'_each_UID'
path_ECG_raw_output = path_ECG_raw+'_each_UID'
path_ECG_timestamp_output = path_ECG_timestamp+'_each_UID'

Path(path_beats_loc_output).mkdir(parents=True, exist_ok=True)
Path(path_beats_rhythm_output).mkdir(parents=True, exist_ok=True)
Path(path_beats_type_output).mkdir(parents=True, exist_ok=True)
Path(path_ECG_valid_output).mkdir(parents=True, exist_ok=True)
Path(path_ECG_raw_output).mkdir(parents=True, exist_ok=True)
Path(path_ECG_timestamp_output).mkdir(parents=True, exist_ok=True)

temp_UIDs = first_3_char_unique[-1:] # Dong, 01/31/2025: for UID 120.
# temp_UIDs = first_3_char_unique
for UID in temp_UIDs:
    # 1: Beats Loc
    path_input = os.path.join(path_beats_loc,UID)
    path_output = path_beats_loc_output
    appendix_name = '_Solo_Beats_Loc.parquet'
    my_func_for_loop(path_input,path_output,appendix_name)
    print('Saved the Beats_Loc parquet of UID',UID)
    
    # 2: Beats Rhythm
    path_input = os.path.join(path_beats_rhythm,UID)
    path_output = path_beats_rhythm_output
    appendix_name = '_Solo_Beats_Rhythm.parquet'
    my_func_for_loop(path_input,path_output,appendix_name)
    print('Saved the Beats_Rhythm parquet of UID',UID)
    
    # 3: Beats Type
    path_input = os.path.join(path_beats_type,UID)
    path_output = path_beats_type_output
    appendix_name = '_Solo_Beats_Type.parquet'
    my_func_for_loop(path_input,path_output,appendix_name)
    print('Saved the Beats_Type parquet of UID',UID)
    
    # 4: ECG Valid
    path_input = os.path.join(path_ECG_valid,UID)
    path_output = path_ECG_valid_output
    appendix_name = '_Solo_ECG_Valid.parquet'
    my_func_for_loop(path_input,path_output,appendix_name)
    print('Saved the ECG_Valid parquet of UID',UID)
    
    # 5: ECG Raw
    path_input = os.path.join(path_ECG_raw,UID)
    path_output = path_ECG_raw_output
    appendix_name = '_Solo_ECG_Raw.parquet'
    my_func_for_loop(path_input,path_output,appendix_name)
    print('Saved the ECG_Raw parquet of UID',UID)
    
    # 6: ECG Timestamp
    path_input = os.path.join(path_ECG_timestamp,UID)
    path_output = path_ECG_timestamp_output
    appendix_name = '_Solo_ECG_Timestamp.parquet'
    my_func_for_loop(path_input,path_output,appendix_name)
    print('Saved the ECG_Timestamp parquet of UID',UID)
# Out:
# Debug: 0 / 5686 : 120_2021_08_05_15_07_29_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 1 / 5686 : 120_2021_08_07_17_09_15_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 2 / 5686 : 120_2021_08_07_17_19_24_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 3 / 5686 : 120_2021_08_07_17_29_28_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 4 / 5686 : 120_2021_08_07_17_39_31_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 5 / 5686 : 120_2021_08_07_17_49_34_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 6 / 5686 : 120_2021_08_07_17_59_38_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 7 / 5686 : 120_2021_08_07_18_09_41_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 8 / 5686 : 120_2021_08_07_18_19_44_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 9 / 5686 : 120_2021_08_07_18_29_47_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 10 / 5686 : 120_2021_08_07_18_39_51_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 11 / 5686 : 120_2021_08_07_18_49_54_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 12 / 5686 : 120_2021_08_07_18_59_57_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 13 / 5686 : 120_2021_08_07_19_10_00_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 14 / 5686 : 120_2021_08_07_19_21_33_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 15 / 5686 : 120_2021_08_07_19_31_37_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 16 / 5686 : 120_2021_08_07_19_41_40_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 17 / 5686 : 120_2021_08_07_19_46_52_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 18 / 5686 : 120_2021_08_07_19_56_55_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 19 / 5686 : 120_2021_08_07_20_07_29_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 20 / 5686 : 120_2021_08_07_20_17_32_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug: 21 / 5686 : 120_2021_08_07_20_27_35_Solo_Beats_Loc.parquet
# Debug: Index([], dtype='object')
# Debug:
#        '120_2021_08_12_23_44_23_ppg_0007.txt',
#        '120_2021_08_12_23_44_23_ppg_0008.txt',
#        '120_2021_08_12_23_44_23_ppg_0009.txt'],
#       dtype='object')
# Debug: 554 / 5686 : 120_2021_08_12_23_54_27_Solo_Beats_Loc.parquet
# Debug: Index(['120_2021_08_12_23_54_27_ppg_0000.txt',
#        '120_2021_08_12_23_54_27_ppg_0001.txt',
#        '120_2021_08_12_23_54_27_ppg_0002.txt',
#        '120_2021_08_12_23_54_27_ppg_0003.txt',
#        '120_2021_08_12_23_54_27_ppg_0004.txt',
#        '120_2021_08_12_23_54_27_ppg_0005.txt',
#        '120_2021_08_12_23_54_27_ppg_0006.txt',
#        '120_2021_08_12_23_54_27_ppg_0007.txt',
#        '120_2021_08_12_23_54_27_ppg_0008.txt',
#        '120_2021_08_12_23_54_27_ppg_0009.txt'],
#       dtype='object')
# Debug: 555 / 5686 : 120_2021_08_13_00_04_30_Solo_Beats_Loc.parquet
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 93
#      91 path_output = path_beats_loc_output
#      92 appendix_name = '_Solo_Beats_Loc.parquet'
# ---> 93 my_func_for_loop(path_input,path_output,appendix_name)
#      94 print('Saved the Beats_Loc parquet of UID',UID)
#      96 # 2: Beats Rhythm
#
# Cell In[6], line 45, in my_func_for_loop(path_input, path_output, appendix_name)
#      43 list_of_files = my_func_all_files(path_input)
#      44 if len(list_of_files) > 0:
# ---> 45     df_all = my_func_concate_df(list_of_files,path_input)
#      47     # Save the bigger parquet file for each UID.
#      48     temp_file = os.path.join(path_output,UID+appendix_name)
#
# Cell In[6], line 29, in my_func_concate_df(list_of_files_loc, path_input)
#      26 for count_ii,this_file_name in enumerate(list_of_files_loc):
#      27     # Read parquet file.
#      28     print('Debug:',count_ii,'/',total_ii,':',this_file_name)
# ---> 29     df_test_loc = pd.read_parquet(os.path.join(path_input,this_file_name), engine="fastparquet")
#      30     print('Debug:',df_test_loc.columns)
#      31     # Save it in a dataframe.
#
# File ~/anaconda3/envs/CS330_torch/lib/python3.11/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# File ~/anaconda3/envs/CS330_torch/lib/python3.11/site-packages/pandas/io/parquet.py:403, in FastParquetImpl.read(self, path, columns, filters, storage_options, filesystem, **kwargs)
#     401 try:
#     402     parquet_file = self.api.ParquetFile(path, **parquet_kwargs)
# --> 403     return parquet_file.to_pandas(columns=columns, filters=filters, **kwargs)
#     404 finally:
#     405     if handles is not None:
#
# File ~/anaconda3/envs/CS330_torch/lib/python3.11/site-packages/fastparquet/api.py:790, in ParquetFile.to_pandas(self, columns, categories, filters, index, row_filter, dtypes)
#     786         continue
#     787     parts = {name: (v if name.endswith('-catdef')
#     788                     else v[start:start + thislen])
#     789              for (name, v) in views.items()}
# --> 790     self.read_row_group_file(rg, columns, categories, index,
#     791                              assign=parts, partition_meta=self.partition_meta,
#     792                              row_filter=sel, infile=infile)
#     793     start += thislen
#     794 return df
#
# File ~/anaconda3/envs/CS330_torch/lib/python3.11/site-packages/fastparquet/api.py:388, in ParquetFile.read_row_group_file(self, rg, columns, categories, index, assign, partition_meta, row_filter, infile)
#     385     ret = True
#     386 f = infile or self.open(fn, mode='rb')
# --> 388 core.read_row_group(
#     389     f, rg, columns, categories, self.schema, self.cats,
#     390     selfmade=self.selfmade, index=index,
#     391     assign=assign, scheme=self.file_scheme, partition_meta=partition_meta,
#     392     row_filter=row_filter
#     393 )
#     394 if ret:
#     395     return df
#
# File ~/anaconda3/envs/CS330_torch/lib/python3.11/site-packages/fastparquet/core.py:645, in read_row_group(file, rg, columns, categories, schema_helper, cats, selfmade, index, assign, scheme, partition_meta, row_filter)
#     643 if assign is None:
#     644     raise RuntimeError('Going with pre-allocation!')
# --> 645 read_row_group_arrays(file, rg, columns, categories, schema_helper,
#     646                       cats, selfmade, assign=assign, row_filter=row_filter)
#     648 for cat in cats:
#     649     if cat not in assign:
#     650         # do no need to have partition columns in output
#
# File ~/anaconda3/envs/CS330_torch/lib/python3.11/site-packages/fastparquet/core.py:615, in read_row_group_arrays(file, rg, columns, categories, schema_helper, cats, selfmade, assign, row_filter)
#     612     continue
#     613 remains.discard(name)
# --> 615 read_col(column, schema_helper, file, use_cat=name+'-catdef' in out,
#     616          selfmade=selfmade, assign=out[name],
#     617          catdef=out.get(name+'-catdef', None),
#     618          row_filter=row_filter)
#     620 if _is_map_like(schema_helper, column):
#     621     # TODO: could be done in fast loop in _assemble_objects?
#     622     if name not in maps:
#
# File ~/anaconda3/envs/CS330_torch/lib/python3.11/site-packages/fastparquet/core.py:519, in read_col(column, schema_helper, infile, use_cat, selfmade, assign, catdef, row_filter)
#     517 else:
#     518     skip_nulls = False
# --> 519 defi, rep, val = read_data_page(infile, schema_helper, ph, cmd,
#     520                                 skip_nulls, selfmade=selfmade)
#     521 max_defi = schema_helper.max_definition_level(cmd.path_in_schema)
#     522 if isinstance(row_filter, np.ndarray):
#
# File ~/anaconda3/envs/CS330_torch/lib/python3.11/site-packages/fastparquet/core.py:113, in read_data_page(f, helper, header, metadata, skip_nulls, selfmade)
#     107 """Read a data page: definitions, repetitions, values (in order)
#     108
#     109 Only values are guaranteed to exist, e.g., for a top-level, required
#     110 field.
#     111 """
#     112 daph = header.data_page_header
# --> 113 raw_bytes = _read_page(f, header, metadata)
#     114 io_obj = encoding.NumpyIO(raw_bytes)
#     116 repetition_levels = read_rep(io_obj, daph, helper, metadata)
#
# File ~/anaconda3/envs/CS330_torch/lib/python3.11/site-packages/fastparquet/core.py:19, in _read_page(file_obj, page_header, column_metadata)
#      16 def _read_page(file_obj, page_header, column_metadata):
#      17     """Read the data page from the given file-object and convert it to raw,
#      18     uncompressed bytes (if necessary)."""
# ---> 19     raw_bytes = file_obj.read(page_header.compressed_page_size)
#      20     raw_bytes = decompress_data(
#      21         raw_bytes,
#      22         page_header.uncompressed_page_size,
#      23         column_metadata.codec,
#      24     )
#      26     if column_metadata.codec:
#
# File ~/anaconda3/envs/CS330_torch/lib/python3.11/site-packages/fastparquet/cencoding.pyx:352, in fastparquet.cencoding.NumpyIO.read()
#
# TypeError: an integer is required

# %%
path_input = '/mnt/r/ENGR_Chon/NIH_Pulsewatch_Database/Parquet_Files/Solo_Beats_Loc/120'
this_file_name = '120_2021_08_13_00_04_30_Solo_Beats_Loc.parquet' # Dong, 01/31/2025: this file has an error.
# this_file_name = '120_2021_08_13_00_24_36_Solo_Beats_Loc.parquet'
df_test_loc = pd.read_parquet(os.path.join(path_input,this_file_name), engine="fastparquet")
