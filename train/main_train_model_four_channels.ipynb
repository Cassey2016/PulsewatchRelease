# %%
# Step 0-0: Map personal Google drive to here.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_your_repo = r'/content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease'
path_subfolder = r'train'
filename_code = 'run_train_model_four_channels.py'
import os
code_to_run = os.path.join(path_your_repo,path_subfolder,filename_code)

# %%
# Run the main code.
# !python3 {code_to_run}
# Out:
# The date and time suffix of the model file is 2025_01_15_22_52_18
# ---System config---
# flag_linux True type <class 'bool'>
# flag_HPC False type <class 'bool'>
# flag_Colab True type <class 'bool'>
# ---Training data config---
# fold_name fold_2 type <class 'str'>
# data_dim 1D_PPG_HR_ACC_rescaleHR type <class 'str'>
# dataset_name Pulsewatch type <class 'str'>
# normalize_type zero_one_normalize type <class 'str'>
# data_format pt type <class 'str'>
# n_classes 3 type <class 'int'>
# ---Model config---
# str_which_model RNN-GRU type <class 'str'>
# flag_resume_training True type <class 'bool'>
# batch_size 32 type <class 'int'>
# loss_type default type <class 'str'>
# learning_rate 0.0001 type <class 'float'>
# num_iterations 200 type <class 'int'>
# patience 10 type <class 'int'>
# ---Output config---
# filename_output train_RNN_GRU_20240712_fold_2.csv type <class 'str'>
# output_folder_name TestRNNGRU_HR_ACC_rescaleHR type <class 'str'>
# Inside Linux
# Inside Colab
# path_for_utils: /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils
# path_for_models: /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/model
# Debug: your_computer_name 0879ec0a405a
# Debug: You are in Google Colab.
# Debug 01/12/2025: dict_paths {'data_path': '/content/PPG_filt_30sec_HR_pt', 'tar_path': '/content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/tar_PT_1D_PPG_HR_Pulsewatch', 'ACC_path': '/content/PPG_Elgendi_30sec_HR_ACC_pt', 'tar_ACC_path': '/content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/tar_PPG_Elgendi_30sec_HR_ACC_pt', 'aug_path': '', 'tar_aug_path': '', 'labels_path': '/content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/Adjudication_UConn/final_attemp_4_1_Dong_Ohm', 'saving_path': '/content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/Checkpoint_Colab/TestRNNGRU_HR_ACC_rescaleHR', 'path_train_val_test_split': '/content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/SMOTE_everything_fold_2_2024_03_30'}
# dict_paths[data_path] /content/PPG_filt_30sec_HR_pt
# dict_paths[tar_path] /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/tar_PT_1D_PPG_HR_Pulsewatch
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/002
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/003
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/005
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/007
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/011
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/012
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/014
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/013
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/017
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/020
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/021
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/022
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/024
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/026
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/027
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/028
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/029
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/034
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/030
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/035
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/036
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/037
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/038
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/039
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/041
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/042
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/044
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/045
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/047
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/049
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/050
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/052
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/053
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/054
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/055
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/056
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/057
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/058
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/063
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/064
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/068
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/069
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/070
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/073
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/074
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/075
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/077
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/078
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/080
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/082
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/083
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/084
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/087
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/086
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/088
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/089
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/090
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/091
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/093
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/094
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/098
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/099
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/100
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/101
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/104
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/106
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/109
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/110
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/111
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/112
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/113
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/119
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/118
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/120
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/302
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/301
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/305
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/306
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/310
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/307
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/312
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/311
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/318
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/319
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/320
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/321
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/324
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/322
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/325
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/327
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/329
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/400
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/402
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/405
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/406
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/407
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/408
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/409
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/410
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/413
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/414
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/415
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/416
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/419
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/420
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/421
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/422
# Tarred folder exists, skipped untar: /content/PPG_filt_30sec_HR_pt/423
# Debug: data_dim 1D_PPG_HR_ACC_rescaleHR
# Debug: ACC_path /content/PPG_Elgendi_30sec_HR_ACC_pt
# Debug: tar_ACC_path /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/tar_PPG_Elgendi_30sec_HR_ACC_pt
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/002
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/003
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/005
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/007
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/011
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/012
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/014
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/013
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/017
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/020
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/021
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/022
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/024
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/026
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/027
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/028
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/029
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/034
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/030
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/035
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/036
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/037
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/038
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/039
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/041
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/042
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/044
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/045
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/047
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/050
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/049
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/052
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/053
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/054
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/055
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/056
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/057
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/058
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/063
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/064
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/068
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/069
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/070
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/074
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/073
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/075
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/077
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/078
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/080
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/082
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/083
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/084
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/086
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/087
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/089
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/088
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/090
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/091
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/093
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/094
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/098
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/099
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/100
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/104
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/101
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/106
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/109
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/110
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/111
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/112
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/113
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/118
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/119
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/306
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/301
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/305
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/302
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/120
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/307
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/311
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/310
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/312
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/318
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/320
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/319
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/321
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/327
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/324
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/325
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/322
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/329
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/400
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/402
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/405
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/406
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/407
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/408
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/409
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/410
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/413
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/414
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/415
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/416
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/419
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/420
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/421
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/422
# Tarred folder exists, skipped untar: /content/PPG_Elgendi_30sec_HR_ACC_pt/423
# Training data file name: fold_2_train_20240330.csv
# Before my_convert_df_to_dict: final_AF_GT_20230921
# 0    31489
# 1     9828
# 2     5070
# Name: count, dtype: int64
# Before my_convert_df_to_dict: (46387, 3)
# After my_convert_df_to_dict: 46387
# Before upsample: y_fold_1_parse
# 0    31489
# 1     9828
# 2     5070
# Name: count, dtype: int64
# X_fold_1_reshape.shape (46387,)
# X_fold_1_reshape.shape (46387, 1)
# y_fold_1_ros
# 2    31489
# 0    31489
# 1    31489
# Name: count, dtype: int64
# Before upsample: y_fold_1_parse
# 0    3936
# 1    1229
# 2     633
# Name: count, dtype: int64
# X_fold_1_reshape.shape (5798,)
# X_fold_1_reshape.shape (5798, 1)
# y_fold_1_ros
# 0    3936
# 1    3936
# 2    3936
# Name: count, dtype: int64
# Debug: len(menu_segment_names) 94467
# Debug: len(menu_segment_labels) 94467
# Debug: resume_training:True, checkpoint_path: /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/Checkpoint_Colab/TestRNNGRU_HR_ACC_rescaleHR
# Debug: dir(train_dataset) ['ACC_path', '__add__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_is_protocol', '_seg_fs', '_seg_sec', 'aug_path', 'data_dim', 'data_format', 'data_path', 'labels_path', 'load_checkpoint', 'my_load_data', 'normalize_type', 'reset_fs', 'reset_sec', 'save_checkpoint', 'segment_labels', 'segment_names', 'standard_scaling', 'zero_one_normalization_scaling', 'zero_one_normalization_scaling_ACC', 'zero_one_normalization_scaling_HR']
# Debug: input_d 4
# Debug init: GRU input_size 16 hidden_size 128 num_layers 1 bias True batch_first True dropout 0 bidirectional True
# Debug: len(train_loader.dataset): 94467 , len(train_loader): 2953
# Debug 01/15/2025: ckpt path: /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/Checkpoint_Colab/TestRNNGRU_HR_ACC_rescaleHR/train_RNN_GRU_20240712_fold_2_epoch_0043_val_loss_0.1470.pt
# Debug 01/15/2025: loading ckpt: /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/Checkpoint_Colab/TestRNNGRU_HR_ACC_rescaleHR/train_RNN_GRU_20240712_fold_2_epoch_0043_val_loss_0.1470.pt
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/model/my_RNN_GRU_model.py:578: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(ckpt_model_file)
# Debug resume ckpt: start_epoch 43
# Training:   0% 0/157 [00:00<?, ?epoch/s]/content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:851: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:939: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:851: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:939: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:851: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:851: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:939: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:939: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# Debug: train_correct 90694
# train_accuracy = 96.0060126816772
# train_loss_Darren_final = 0.10696796756149439
# train_loss_Cassey_final = 0.10698444380333615
# Debug: flag_reload_dataloader False
# Debug: inside validation loop...
# Debug: len(val_indices) 11808
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:851: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:939: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:851: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:851: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:939: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:939: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:851: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:939: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# Debug val: len(val_indices) 11808
# valid_loss = 0.15134873250524608
# valid_accuracy = 94.1819105691057
# Debug: saved model checkpoint with epoch. /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/Checkpoint_Colab/TestRNNGRU_HR_ACC_rescaleHR/train_RNN_GRU_20240712_fold_2_epoch_0043_val_loss_0.1470.pt
# Training:   1% 1/157 [06:39<17:17:54, 399.20s/epoch]/content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:851: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:939: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:851: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:851: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:939: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:939: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:851: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:939: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# Debug: train_correct 90364
# train_accuracy = 95.65668434479765
# train_loss_Darren_final = 0.11820970378204917
# train_loss_Cassey_final = 0.11820492446116562
# Debug: flag_reload_dataloader False
# Debug: inside validation loop...
# Debug: len(val_indices) 11808
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:851: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:939: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:851: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:851: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:939: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:939: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:851: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# /content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/utils/my_dataloader.py:939: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict_pt = torch.load(seg_path)
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/train/run_train_model_four_channels.py", line 38, in <module>
#     my_main.my_main(parser.parse_args())
#   File "/content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/train/my_main.py", line 224, in my_main
#     training_metrics = my_RNN_GRU_model.train_valid_RNN_GRU_model_all(PARAMS_all)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/model/my_RNN_GRU_model.py", line 676, in train_valid_RNN_GRU_model_all
#     save_ckpt_best_model_path, PARAMS_valid = valid_RNN_GRU_model(PARAMS_valid)
#                                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/Public_Datasets/PulsewatchRelease/GitHub/PulsewatchRelease/model/my_RNN_GRU_model.py", line 392, in valid_RNN_GRU_model
#     val_loss += val_loss_batch.item() * len(val_batch['label'])
#                 ^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
