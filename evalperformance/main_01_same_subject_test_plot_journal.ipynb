# %%
import pandas as pd
import os
import sys
import numpy as np
sys.path.append('/mnt/r/ENGR_Chon/Dong/Github_private/Pulsewatch_labeling/DeepBeat/experiments/try_07_eval_models')
import my_model_names

# Combine all dataframes together.
path_all_csv = r'/mnt/r/ENGR_Chon/Dong/Python_generated_results/deep_learning_2023/analysis_2024_07_30/same_subject_test'
test_name = 'same_subject_test'
list_str_model_idx = ['18','19','20','01','02','03','21','22','07','23','24','05','06','08','10','12']
df_all = []
for str_model_idx in list_str_model_idx:
    print('str_model_idx',str_model_idx)
    path_ckpt, file_date, model_name = my_model_names.my_model_names(str_model_idx)
    if str_model_idx == '13' or str_model_idx == '15':
        this_df = pd.read_excel(os.path.join(path_ckpt,model_name+'.xlsx'),index_col=0)
    else:
        this_df = pd.read_csv(os.path.join(path_all_csv,str_model_idx+'_'+model_name+'_'+test_name+'.csv'),index_col=0)
    this_df = this_df.rename(columns={'index': 'class'})
    new_col = [str_model_idx] * this_df.shape[0] # rows
    this_df.insert(0,'str_model_idx',new_col) 
    new_col = [model_name] * this_df.shape[0] # rows
    this_df.insert(1,'model_name',new_col) 

    # Convert the 0-1 value to percentage.
    this_df['avg_TPR'] = this_df['avg_TPR'] * 100
    this_df['avg_TNR'] = this_df['avg_TNR'] * 100
    this_df['avg_PPV'] = this_df['avg_PPV'] * 100
    this_df['avg_NPV'] = this_df['avg_NPV'] * 100
    this_df['avg_FPR'] = this_df['avg_FPR'] * 100
    this_df['avg_FNR'] = this_df['avg_FNR'] * 100
    this_df['avg_FDR'] = this_df['avg_FDR'] * 100
    this_df['avg_ACC'] = this_df['avg_ACC'] * 100
    this_df['avg_micro_auroc'] = this_df['avg_micro_auroc'] * 100
    this_df['avg_macro_auroc'] = this_df['avg_macro_auroc'] * 100
    
    print(this_df.columns)
    
    if len(df_all) < 1:
        df_all = this_df.copy()
    else:
        df_all = pd.concat([df_all, this_df], ignore_index=True, sort=False)

# df_all[['avg_TPR', 'avg_TNR', 'avg_PPV',
#     'avg_NPV', 'avg_FPR', 'avg_FNR', 'avg_FDR', 'avg_ACC',
#     'avg_micro_auroc', 'avg_macro_auroc']].round(decimals=3)
print(df_all)
filename_output = test_name+'_all_models.csv'
df_all.to_csv(os.path.join(path_all_csv,filename_output),header=True,index=False)
# Out:
# /home/doh16101/anaconda3/envs/CS330_torch/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# str_model_idx 18
# Index(['str_model_idx', 'model_name', 'class', 'avg_TPR', 'avg_TNR', 'avg_PPV',
#        'avg_NPV', 'avg_FPR', 'avg_FNR', 'avg_FDR', 'avg_ACC',
#        'avg_micro_auroc', 'avg_macro_auroc'],
#       dtype='object')
# str_model_idx 19
# Index(['str_model_idx', 'model_name', 'class', 'avg_TPR', 'avg_TNR', 'avg_PPV',
#        'avg_NPV', 'avg_FPR', 'avg_FNR', 'avg_FDR', 'avg_ACC',
#        'avg_micro_auroc', 'avg_macro_auroc'],
#       dtype='object')
# str_model_idx 20
# Index(['str_model_idx', 'model_name', 'class', 'avg_TPR', 'avg_TNR', 'avg_PPV',
#        'avg_NPV', 'avg_FPR', 'avg_FNR', 'avg_FDR', 'avg_ACC',
#        'avg_micro_auroc', 'avg_macro_auroc'],
#       dtype='object')
# str_model_idx 01
# Index(['str_model_idx', 'model_name', 'class', 'avg_TPR', 'avg_TNR', 'avg_PPV',
#        'avg_NPV', 'avg_FPR', 'avg_FNR', 'avg_FDR', 'avg_ACC',
#        'avg_micro_auroc', 'avg_macro_auroc'],
#       dtype='object')
# str_model_idx 02
# Index(['str_model_idx', 'model_name', 'class', 'avg_TPR', 'avg_TNR', 'avg_PPV',
#        'avg_NPV', 'avg_FPR', 'avg_FNR', 'avg_FDR', 'avg_ACC',
#        'avg_micro_auroc', 'avg_macro_auroc'],
#       dtype='object')
# str_model_idx 03
# Index(['str_model_idx', 'model_name', 'class', 'avg_TPR', 'avg_TNR', 'avg_PPV',
#        'avg_NPV', 'avg_FPR', 'avg_FNR', 'avg_FDR', 'avg_ACC',
#        'avg_micro_auroc', 'avg_macro_auroc'],
#       dtype='object')
# str_model_idx 21
# Index(['str_model_idx', 'model_name', 'class', 'avg_TPR', 'avg_TNR', 'avg_PPV',
#        'avg_NPV', 'avg_FPR', 'avg_FNR', 'avg_FDR', 'avg_ACC',
#        'avg_micro_auroc', 'avg_macro_auroc'],
#       dtype='object')
# str_model_idx 22
# Index(['str_model_idx', 'model_name', 'class', 'avg_TPR', 'avg_TNR', 'avg_PPV',
#        'avg_NPV', 'avg_FPR', 'avg_FNR', 'avg_FDR', 'avg_ACC',
#        'avg_micro_auroc', 'avg_macro_auroc'],
#       dtype='object')
# str_model_idx 07
# Index(['str_model_idx', 'model_name', 'class', 'avg_TPR', 'avg_TNR', 'avg_PPV',
#        'avg_NPV', 'avg_FPR', 'avg_FNR', 'avg_FDR', 'avg_ACC',
#        'avg_micro_auroc', 'avg_macro_auroc'],
#       dtype='object')
# str_model_idx 23
# Index(['str_model_idx', 'model_name', 'class', 'avg_TPR', 'avg_TNR', 'avg_PPV',
#        'avg_NPV', 'avg_FPR', 'avg_FNR', 'avg_FDR', 'avg_ACC',
#        'avg_micro_auroc', 'avg_macro_auroc'],
#       dtype='object')
# str_model_idx 24
# Index(['str_model_idx', 'model_name', 'class', 'avg_TPR', 'avg_TNR', 'avg_PPV',
#        'avg_NPV', 'avg_FPR', 'avg_FNR', 'avg_FDR', 'avg_ACC',
#        'avg_micro_auroc', 'avg_macro_auroc'],
#       dtype='object')
# str_model_idx 05
# Index(['str_model_idx', 'model_name', 'class', 'avg_TPR', 'avg_TNR', 'avg_PPV',
#        'avg_NPV', 'avg_FPR', 'avg_FNR', 'avg_FDR', 'avg_ACC',
#        'avg_micro_auroc', 'avg_macro_auroc'],
#       dtype='object')
# str_model_idx 06
# Index(['str_model_idx', 'model_name', 'class', 'avg_TPR', 'avg_TNR', 'avg_PPV',
#        'avg_NPV', 'avg_FPR', 'avg_FNR', 'avg_FDR', 'avg_ACC',
#        'avg_micro_auroc', 'avg_macro_auroc'],
#       dtype='object')
# str_model_idx 08
# Index(['str_model_idx', 'model_name', 'class', 'avg_TPR', 'avg_TNR', 'avg_PPV',
#        'avg_NPV', 'avg_FPR', 'avg_FNR', 'avg_FDR', 'avg_ACC',
#        'avg_micro_auroc', 'avg_macro_auroc'],
#       dtype='object')
# str_model_idx 10
# Index(['str_model_idx', 'model_name', 'class', 'avg_TPR', 'avg_TNR', 'avg_PPV',
#        'avg_NPV', 'avg_FPR', 'avg_FNR', 'avg_FDR', 'avg_ACC',
#        'avg_micro_auroc', 'avg_macro_auroc'],
#       dtype='object')
# str_model_idx 12
# Index(['str_model_idx', 'model_name', 'class', 'avg_TPR', 'avg_TNR', 'avg_PPV',
#        'avg_NPV', 'avg_FPR', 'avg_FNR', 'avg_FDR', 'avg_ACC',
#        'avg_micro_auroc', 'avg_macro_auroc'],
#       dtype='object')
#    str_model_idx                                        model_name  class  \
# 0             18       Liu_2022_JAHA_retrained_Pulsewatch_PPG_only      0
# 1             18       Liu_2022_JAHA_retrained_Pulsewatch_PPG_only      1
# 2             18       Liu_2022_JAHA_retrained_Pulsewatch_PPG_only      2
# 3             19  Liu_2022_JAHA_retrained_Pulsewatch_four_channels      0
# 4             19  Liu_2022_JAHA_retrained_Pulsewatch_four_channels      1
# 5             19  Liu_2022_JAHA_retrained_Pulsewatch_four_channels      2
# 6             20                                  Darren_2024_EMBC      0
# 7             20                                  Darren_2024_EMBC      1
# 8             20                                  Darren_2024_EMBC      2
# 9             01                       2D_TFS_ROS_ImageNet_weights      0
# 10            01                       2D_TFS_ROS_ImageNet_weights      1
# 11            01                       2D_TFS_ROS_ImageNet_weights      2
# 12            02                      2D_Poin_ROS_ImageNet_weights      0
# 13            02                      2D_Poin_ROS_ImageNet_weights      1
# 14            02                      2D_Poin_ROS_ImageNet_weights      2
# 15            03                                    1D_PPG_batch32      0
# 16            03                                    1D_PPG_batch32      1
# 17            03                                    1D_PPG_batch32      2
# 18            21                                   1D_PPG_ACC_only      0
# 19            21                                   1D_PPG_ACC_only      1
# 20            21                                   1D_PPG_ACC_only      2
# 21            22                                        1D_HR_only      0
# 22            22                                        1D_HR_only      1
# 23            22                                        1D_HR_only      2
# 24            07                                   1D_HR_ACC_noPPG      0
# 25            07                                   1D_HR_ACC_noPPG      1
# 26            07                                   1D_HR_ACC_noPPG      2
# 27            23                              1D_HR_rescaleHR_only      0
# 28            23                              1D_HR_rescaleHR_only      1
# 29            23                              1D_HR_rescaleHR_only      2
# 30            24                         1D_HR_rescaleHR_ACC_noPPG      0
# 31            24                         1D_HR_rescaleHR_ACC_noPPG      1
# 32            24                         1D_HR_rescaleHR_ACC_noPPG      2
# 33            05                                         1D_PPG_HR      0
# 34            05                                         1D_PPG_HR      1
# 35            05                                         1D_PPG_HR      2
# 36            06                                     1D_PPG_HR_ACC      0
# 37            06                                     1D_PPG_HR_ACC      1
# 38            06                                     1D_PPG_HR_ACC      2
# 39            08                1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR      0
# 40            08                1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR      1
# 41            08                1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR      2
# 42            10          1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR      0
# 43            10          1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR      1
# 44            10          1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR      2
# 45            12               1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k      0
# 46            12               1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k      1
# 47            12               1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k      2
#
#       avg_TPR    avg_TNR    avg_PPV    avg_NPV   avg_FPR    avg_FNR  \
# 0   96.099901  91.182030  95.825795  91.840782  8.817970   3.900099
# 1   89.714713  95.915037  85.654036  97.222018  4.084963  10.285287
# 2   62.089202  96.670487  68.971851  95.387366  3.329513  37.910798
# 3   93.977224  91.561202  95.918346  88.355608  8.438798   6.022776
# 4   97.479863  96.881671  89.476355  99.307349  3.118329   2.520137
# 5   70.294431  96.921906  74.635875  96.303266  3.078094  29.705569
# 6   96.786703  96.234899  98.167310  93.517615  3.765101   3.213297
# 7   97.889010  99.456112  97.968924  99.434087  0.543888   2.110990
# 8   88.689462  97.475198  82.105734  98.549275  2.524802  11.310538
# 9   97.726563  96.870207  98.487610  95.341515  3.129793   2.273437
# 10  98.536514  99.367641  97.682104  99.607939  0.632359   1.463486
# 11  90.007894  98.364943  87.430675  98.737223  1.635057   9.992106
# 12  95.681332  95.283366  97.689754  91.376582  4.716634   4.318668
# 13  98.457227  98.291618  93.915697  99.580763  1.708382   1.542773
# 14  82.102497  97.310314  79.688430  97.715188  2.689686  17.897503
# 15  90.727321  95.684484  97.767657  83.235219  4.315516   9.272679
# 16  89.913508  94.186279  81.980159  97.273097  5.813721  10.086492
# 17  67.318266  93.166488  55.257685  95.844546  6.833512  32.681734
# 18  86.444562  94.307030  96.937897  77.067806  5.692970  13.555438
# 19  93.002026  94.775624  82.654495  98.084439  5.224376   6.997974
# 20  71.009390  91.085580  50.302647  96.193105  8.914420  28.990610
# 21  88.264296  93.109871  96.369158  79.558095  6.890129  11.735704
# 22  89.845283  95.991755  85.777856  97.239826  4.008245  10.154717
# 23  72.060881  91.186505  52.635380  96.244996  8.813495  27.939119
# 24  86.739557  94.636595  97.134231  77.673319  5.363405  13.260443
# 25  95.935273  96.675686  88.738236  98.884912  3.324314   4.064727
# 26  79.507873  91.245246  56.284189  97.215934  8.754754  20.492127
# 27  89.928403  93.251518  96.520411  82.055356  6.748482  10.071597
# 28  93.744337  96.198734  86.917009  98.284972  3.801266   6.255663
# 29  69.546235  92.831906  57.678525  95.988424  7.168094  30.453765
# 30  86.269582  95.592416  97.632048  77.247968  4.407584  13.730418
# 31  94.875816  96.815048  88.890427  98.603286  3.184952   5.124184
# 32  80.705818  90.315677  53.149880  97.348096  9.684323  19.294182
# 33  91.538986  94.146297  97.026843  84.293217  5.853703   8.461014
# 34  91.871868  96.467693  87.805053  97.796560  3.532307   8.128132
# 35  69.019970  92.992255  55.595962  96.017177  7.007745  30.980030
# 36  86.306226  95.377312  97.495984  76.981077  4.622688  13.693774
# 37  94.752675  96.259158  87.141165  98.565322  3.740842   5.247325
# 38  76.128007  90.303732  50.121484  96.743809  9.696268  23.871993
# 39  88.173947  95.803233  97.774921  79.585661  4.196767  11.826053
# 40  96.869774  97.131020  90.128299  99.143647  2.868980   3.130226
# 41  82.313003  92.085531  57.783032  97.610618  7.914469  17.686997
# 42  90.001951  95.048699  97.428952  82.069666  4.951301   9.998049
# 43  95.812959  95.803575  86.029392  98.842172  4.196425   4.187041
# 44  75.688991  93.855066  60.999486  96.826468  6.144934  24.311009
# 45  91.069334  93.786182  96.825069  83.452575  6.213818   8.930666
# 46  96.381670  97.217585  90.326263  99.012722  2.782415   3.618330
# 47  75.307796  93.942123  61.326353  96.760435  6.057877  24.692204
#
#       avg_FDR    avg_ACC  avg_micro_auroc  avg_macro_auroc
# 0    4.174205  94.512929        97.579273        95.176300
# 1   14.345964  94.608611        97.579273        95.176300
# 2   31.028149  92.827685        97.579273        95.176300
# 3    4.081654  93.204634        98.298917        97.628076
# 4   10.523645  97.007168        98.298917        97.628076
# 5   25.364125  93.947065        98.298917        97.628076
# 6    1.832690  96.606701        99.613601        99.366209
# 7    2.031076  99.124060        99.613601        99.366209
# 8   17.894266  96.485777        99.613601        99.366209
# 9    1.512390  97.448527        50.000000        50.000000
# 10   2.317896  99.192686        50.000000        50.000000
# 11  12.569325  97.431094        50.000000        50.000000
# 12   2.310246  95.551673        50.000000        50.000000
# 13   6.084303  98.325926        50.000000        50.000000
# 14  20.311570  95.594261        50.000000        50.000000
# 15   2.232343  92.332260        96.628189        95.250614
# 16  18.019841  93.291517        96.628189        95.250614
# 17  44.742315  90.298552        96.628189        95.250614
# 18   3.062103  88.999128        94.998654        94.984064
# 19  17.345505  94.405430        94.998654        94.984064
# 20  49.697353  88.858163        94.998654        94.984064
# 21   3.630842  89.828929        96.063822        94.176935
# 22  14.222144  94.692414        96.063822        94.176935
# 23  47.364620  89.037500        96.063822        94.176935
# 24   2.865769  89.291005        96.395459        96.423790
# 25  11.261764  96.518447        96.395459        96.423790
# 26  43.715811  89.904923        96.395459        96.423790
# 27   3.479589  90.997247        97.163202        95.521681
# 28  13.082991  95.680142        97.163202        95.521681
# 29  42.321475  90.212921        97.163202        95.521681
# 30   2.367952  89.282531        96.494030        96.473327
# 31  11.109573  96.406526        96.494030        96.473327
# 32  46.850120  89.219373        96.494030        96.473327
# 33   2.973157  92.388094        97.034430        94.772871
# 34  12.194947  95.499110        97.034430        94.772871
# 35  44.404038  90.325431        97.034430        94.772871
# 36   2.504016  89.244321        95.891076        95.657859
# 37  12.858835  95.942871        95.891076        95.657859
# 38  49.878516  88.701533        95.891076        95.657859
# 39   2.225079  90.642521        97.161793        97.093249
# 40   9.871701  97.075484        97.161793        97.093249
# 41  42.216968  90.973640        97.161793        97.093249
# 42   2.571048  91.641330        96.141514        96.229943
# 43  13.970608  95.805310        96.141514        96.229943
# 44  39.000514  91.817146        96.141514        96.229943
# 45   3.174931  91.950036        97.244880        96.665413
# 46   9.673737  97.041016        97.244880        96.665413
# 47  38.673647  91.835905        97.244880        96.665413

# %%
def my_convert_model_name(model_name):
    if model_name == 'Poh_2018_Heart_same_subject_test':
        output_name = 'Poh et al.'
    elif model_name == 'Han_2020_Sensors_same_subject_test':
        output_name = 'Han at al.'
    elif model_name == '2D_TFS_ROS_ImageNet_weights':
        output_name = '2D TFS'
    elif model_name == '2D_Poin_ROS_ImageNet_weights':
        output_name = '2D Poincare'
    elif model_name == '1D_PPG_batch32':
        output_name = '1D PPG'
    elif model_name == '1D_PPG_batch512':
        output_name = '1D PPG (batch size 512)'
    elif model_name == '1D_PPG_HR':
        output_name = '1D PPG+HR'
    elif model_name == '1D_PPG_HR_ACC':
        output_name = '1D PPG+HR+ACC'
    elif model_name == '1D_HR_ACC_noPPG':
        output_name = '1D HR+ACC'
    elif model_name == '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR':
        output_name = '1D all four sig.'
    elif model_name == '1D_PPG_Elgendi-HR_ACC':
        output_name = '1D PPG + HR + ACC (Elgendi et al.)'
    elif model_name == '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR':
        output_name = '1D all four sig. (E. peak)'
    elif model_name == '1D_PPG_WEPD-HR_ACC_rescale-HR_aug30k':
        output_name = '1D four channels (augmented 30k)'
    elif model_name == '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k':
        output_name = '1D all four sig. (aug.)'
    elif model_name == 'Liu_2022_JAHA_retrained_Pulsewatch_PPG_only':
        output_name = 'Liu et al. (retrained)'
    elif model_name == 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels':
        output_name = 'Liu et al. (retrained, four sig.)'
    elif model_name == 'Darren_2024_EMBC':
        output_name = 'Chen et al. (retrained, four sig.)'
    elif model_name == '1D_PPG_ACC_only':
        output_name = '1D PPG+ACC'
    elif model_name == '1D_HR_only':
        output_name = '1D HR'
    elif model_name == '1D_HR_rescaleHR_only':
        output_name = '1D HR+rescaled HR'
    elif model_name == '1D_HR_rescaleHR_ACC_noPPG':
        output_name = '1D HR+rescaled HR+ACC'

    return output_name

# %%
my_col_names = ['avg_TPR', 'avg_TNR', 'avg_PPV', 'avg_NPV', 'avg_ACC',
       'avg_micro_auroc', 'avg_macro_auroc']
my_plot_names = ['Averaged Sensitivity', 'Averaged Specificity', 'Averaged Precision', 'Averaged NPV', 'Averaged Accuracy',
       'Averaged Micro AUROC', 'Averaged Macro AUROC']
import matplotlib.pyplot as plt
# plt.figure(figsize=(50,20))
fig, axs = plt.subplots(1, 7, figsize=(60, 5))
color_green = (32, 99, 27) #'#20631B'
color_red = (213, 32, 42) #'#FF7575'
color_yellow = (255, 204, 0) #'#FFCC00'
for this_idx, this_col_name in enumerate(my_col_names):
    this_df = df_all[['str_model_idx','model_name','class',this_col_name]]
    temp_df = this_df.loc[this_df['class'] == 0]
    col_0 = temp_df[this_col_name].to_numpy()

    temp_df = this_df.loc[this_df['class'] == 1]
    col_1 = temp_df[this_col_name].to_numpy()

    temp_df = this_df.loc[this_df['class'] == 2]
    col_2 = temp_df[this_col_name].to_numpy()

    # col_0 = np.expand_dims(col_0, axis=1)
    # col_1 = np.expand_dims(col_1, axis=1)
    # col_2 = np.expand_dims(col_2, axis=1)
    # import numpy as np
    col_plot = np.concatenate((np.expand_dims(col_0, axis=1), np.expand_dims(col_1, axis=1), np.expand_dims(col_2, axis=1)), axis=1)
    if this_col_name[-5:] == 'auroc' or this_col_name[-3:] == 'ACC':
        plot_y_min = np.min(col_plot[4:,:])
        plot_y_max = np.max(col_plot[4:,:])
    else:
        plot_y_min = np.min(col_plot)
        plot_y_max = np.max(col_plot)
    this_seq = this_df['model_name'].values.tolist()
    print(this_seq)

    def f7(seq):
        seen = set()
        seen_add = seen.add
        return [x for x in seq if not (x in seen or seen_add(x))]

    list_model_name = f7(this_seq)
    list_converted_model_name = []
    for this_name in list_model_name:
        this_converted_name = my_convert_model_name(this_name)
        list_converted_model_name.append(this_converted_name)

    x = np.arange(0,len(list_converted_model_name)*1.5,1.5)
    width = 0.5


    # plt.subplot(my_subplot_idx[this_idx])
    # plt.title(this_col_name, fontsize=18)
    axs[this_idx].set_title(my_plot_names[this_idx], fontsize=18)
    # if this_idx == 0:
    axs[this_idx].bar(x-width+0.1, col_0, width, label='NSR', color=np.array(color_green)/255) # Dark blue
    axs[this_idx].bar(x, col_1, width, label='AF', color=np.array(color_red)/255) # Pink
    axs[this_idx].bar(x+width-0.1, col_2, width, label='PAC/PVC',color=np.array(color_yellow)/255) # Yellow

    # else:
    #     axs[this_idx].bar(x-width, col_0, width, color=np.array(color_green)/255) # Dark blue
    #     axs[this_idx].bar(x, col_1, width, color=np.array(color_red)/255) # Pink
    #     axs[this_idx].bar(x+width, col_2, width, color=np.array(color_yellow)/255) # Yellow

    text_adjust_x = 0.05
    for xx,yy in zip(x-width+text_adjust_x,col_0):
        axs[this_idx].text(xx+0.05, yy, '{:.2f}'.format(yy), color='white', fontweight='bold', horizontalalignment='center', verticalalignment='top',rotation = 90)
    for xx,yy in zip(x+text_adjust_x,col_1):
        axs[this_idx].text(xx, yy, '{:.2f}'.format(yy), color='white', fontweight='bold', horizontalalignment='center', verticalalignment='top',rotation = 90)
    for xx,yy in zip(x+width+text_adjust_x,col_2):
        axs[this_idx].text(xx-0.1, yy, '{:.2f}'.format(yy), color='black', fontweight='bold', horizontalalignment='center', verticalalignment='top',rotation = 90)

    axs[this_idx].set_xlabel('model names')
    axs[this_idx].set_ylabel('Percentage')
    axs[this_idx].set_xticks(x, list_converted_model_name, fontsize=15,rotation=90)
    # ax = plt.gca()
    # axs[this_idx].set_ylim((plot_y_min-0.2*(plot_y_max-plot_y_min), 100))
    # if this_idx == 0:
    axs[this_idx].legend(loc='upper left', bbox_to_anchor=(0.5, 0.3), ncol=1, labelspacing=0.5, fontsize=14)


# plt.tight_layout(w_pad=6)
# plt.show()
# plt.margins(0,0)
plt.savefig(os.path.join(path_all_csv,test_name+'_all_journal'+'.png'), dpi=300, bbox_inches='tight',pad_inches = 0)
# Out:
# ['Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Darren_2024_EMBC', 'Darren_2024_EMBC', 'Darren_2024_EMBC', '2D_TFS_ROS_ImageNet_weights', '2D_TFS_ROS_ImageNet_weights', '2D_TFS_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '1D_PPG_batch32', '1D_PPG_batch32', '1D_PPG_batch32', '1D_PPG_ACC_only', '1D_PPG_ACC_only', '1D_PPG_ACC_only', '1D_HR_only', '1D_HR_only', '1D_HR_only', '1D_HR_ACC_noPPG', '1D_HR_ACC_noPPG', '1D_HR_ACC_noPPG', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_ACC_noPPG', '1D_HR_rescaleHR_ACC_noPPG', '1D_HR_rescaleHR_ACC_noPPG', '1D_PPG_HR', '1D_PPG_HR', '1D_PPG_HR', '1D_PPG_HR_ACC', '1D_PPG_HR_ACC', '1D_PPG_HR_ACC', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k']
# ['Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Darren_2024_EMBC', 'Darren_2024_EMBC', 'Darren_2024_EMBC', '2D_TFS_ROS_ImageNet_weights', '2D_TFS_ROS_ImageNet_weights', '2D_TFS_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '1D_PPG_batch32', '1D_PPG_batch32', '1D_PPG_batch32', '1D_PPG_ACC_only', '1D_PPG_ACC_only', '1D_PPG_ACC_only', '1D_HR_only', '1D_HR_only', '1D_HR_only', '1D_HR_ACC_noPPG', '1D_HR_ACC_noPPG', '1D_HR_ACC_noPPG', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_ACC_noPPG', '1D_HR_rescaleHR_ACC_noPPG', '1D_HR_rescaleHR_ACC_noPPG', '1D_PPG_HR', '1D_PPG_HR', '1D_PPG_HR', '1D_PPG_HR_ACC', '1D_PPG_HR_ACC', '1D_PPG_HR_ACC', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k']
# ['Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Darren_2024_EMBC', 'Darren_2024_EMBC', 'Darren_2024_EMBC', '2D_TFS_ROS_ImageNet_weights', '2D_TFS_ROS_ImageNet_weights', '2D_TFS_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '1D_PPG_batch32', '1D_PPG_batch32', '1D_PPG_batch32', '1D_PPG_ACC_only', '1D_PPG_ACC_only', '1D_PPG_ACC_only', '1D_HR_only', '1D_HR_only', '1D_HR_only', '1D_HR_ACC_noPPG', '1D_HR_ACC_noPPG', '1D_HR_ACC_noPPG', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_ACC_noPPG', '1D_HR_rescaleHR_ACC_noPPG', '1D_HR_rescaleHR_ACC_noPPG', '1D_PPG_HR', '1D_PPG_HR', '1D_PPG_HR', '1D_PPG_HR_ACC', '1D_PPG_HR_ACC', '1D_PPG_HR_ACC', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k']
# ['Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Darren_2024_EMBC', 'Darren_2024_EMBC', 'Darren_2024_EMBC', '2D_TFS_ROS_ImageNet_weights', '2D_TFS_ROS_ImageNet_weights', '2D_TFS_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '1D_PPG_batch32', '1D_PPG_batch32', '1D_PPG_batch32', '1D_PPG_ACC_only', '1D_PPG_ACC_only', '1D_PPG_ACC_only', '1D_HR_only', '1D_HR_only', '1D_HR_only', '1D_HR_ACC_noPPG', '1D_HR_ACC_noPPG', '1D_HR_ACC_noPPG', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_ACC_noPPG', '1D_HR_rescaleHR_ACC_noPPG', '1D_HR_rescaleHR_ACC_noPPG', '1D_PPG_HR', '1D_PPG_HR', '1D_PPG_HR', '1D_PPG_HR_ACC', '1D_PPG_HR_ACC', '1D_PPG_HR_ACC', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k']
# ['Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Darren_2024_EMBC', 'Darren_2024_EMBC', 'Darren_2024_EMBC', '2D_TFS_ROS_ImageNet_weights', '2D_TFS_ROS_ImageNet_weights', '2D_TFS_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '1D_PPG_batch32', '1D_PPG_batch32', '1D_PPG_batch32', '1D_PPG_ACC_only', '1D_PPG_ACC_only', '1D_PPG_ACC_only', '1D_HR_only', '1D_HR_only', '1D_HR_only', '1D_HR_ACC_noPPG', '1D_HR_ACC_noPPG', '1D_HR_ACC_noPPG', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_ACC_noPPG', '1D_HR_rescaleHR_ACC_noPPG', '1D_HR_rescaleHR_ACC_noPPG', '1D_PPG_HR', '1D_PPG_HR', '1D_PPG_HR', '1D_PPG_HR_ACC', '1D_PPG_HR_ACC', '1D_PPG_HR_ACC', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k']
# ['Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Darren_2024_EMBC', 'Darren_2024_EMBC', 'Darren_2024_EMBC', '2D_TFS_ROS_ImageNet_weights', '2D_TFS_ROS_ImageNet_weights', '2D_TFS_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '1D_PPG_batch32', '1D_PPG_batch32', '1D_PPG_batch32', '1D_PPG_ACC_only', '1D_PPG_ACC_only', '1D_PPG_ACC_only', '1D_HR_only', '1D_HR_only', '1D_HR_only', '1D_HR_ACC_noPPG', '1D_HR_ACC_noPPG', '1D_HR_ACC_noPPG', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_ACC_noPPG', '1D_HR_rescaleHR_ACC_noPPG', '1D_HR_rescaleHR_ACC_noPPG', '1D_PPG_HR', '1D_PPG_HR', '1D_PPG_HR', '1D_PPG_HR_ACC', '1D_PPG_HR_ACC', '1D_PPG_HR_ACC', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k']
# ['Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_PPG_only', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Liu_2022_JAHA_retrained_Pulsewatch_four_channels', 'Darren_2024_EMBC', 'Darren_2024_EMBC', 'Darren_2024_EMBC', '2D_TFS_ROS_ImageNet_weights', '2D_TFS_ROS_ImageNet_weights', '2D_TFS_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '2D_Poin_ROS_ImageNet_weights', '1D_PPG_batch32', '1D_PPG_batch32', '1D_PPG_batch32', '1D_PPG_ACC_only', '1D_PPG_ACC_only', '1D_PPG_ACC_only', '1D_HR_only', '1D_HR_only', '1D_HR_only', '1D_HR_ACC_noPPG', '1D_HR_ACC_noPPG', '1D_HR_ACC_noPPG', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_only', '1D_HR_rescaleHR_ACC_noPPG', '1D_HR_rescaleHR_ACC_noPPG', '1D_HR_rescaleHR_ACC_noPPG', '1D_PPG_HR', '1D_PPG_HR', '1D_PPG_HR', '1D_PPG_HR_ACC', '1D_PPG_HR_ACC', '1D_PPG_HR_ACC', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_WEPD-HR_ACC_rescale-WEPD-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_Elgendi-HR_ACC_rescale-Elgendi-HR', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k', '1D_PPG_WEPD-HR_ACC_rescale-HR_aug5k']
